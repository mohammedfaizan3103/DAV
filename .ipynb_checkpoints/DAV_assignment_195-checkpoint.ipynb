# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Data Loading and Inspections

# %%
df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')  

print("First 5 rows:\n")
df.head()
# Out:
# First 5 rows:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
print("\nData types:\n", df.dtypes)
print("\nMissing values:\n", df.isna().sum())
# Out:
# Data types:
#  Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object
#
# Missing values:
#  Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %% [markdown]
# ## Data Cleaning with numpy/pandas

# %%
# Convert User_Score to numeric
df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')

# Replace missing values in numerical columns with median
df['Critic_Score'] = df['Critic_Score'].fillna(np.nanmedian(df['Critic_Score']))
df['User_Score'] = df['User_Score'].fillna(np.nanmedian(df['User_Score']))

# Convert 'Year_of_Release' to numeric
df['Year_of_Release'] = pd.to_numeric(df['Year_of_Release'], errors='coerce')

# Drop rows with critical missing values
df.dropna(subset=['Name', 'Global_Sales'], inplace=True)

# Check cleaned data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16717 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16717 non-null  object
#  2   Year_of_Release  16448 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16663 non-null  object
#  5   NA_Sales         16717 non-null  float64
#  6   EU_Sales         16717 non-null  float64
#  7   JP_Sales         16717 non-null  float64
#  8   Other_Sales      16717 non-null  float64
#  9   Global_Sales     16717 non-null  float64
#  10  Critic_Score     16717 non-null  float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       16717 non-null  float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 2.2+ MB

# %% [markdown]
# ## Data Analysis Operations

# %% [markdown]
# ### Basic Analysis (Numpy and Pandas)

# %%
sales_data = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].values

print("Array shape:", sales_data.shape)
print("Data type:", sales_data.dtype)
print("Total global sales (million):", np.sum(sales_data[:, 4]))
# Out:
# Array shape: (16717, 5)
# Data type: float64
# Total global sales (million): 8917.88

# %% [markdown]
# #### Array slicing examples

# %%
na_sales = sales_data[:, 0]  
first_5_eu_sales = sales_data[:5, 1]  
print("NA Sales example:", na_sales[:5])
print("First 5 EU sales:", first_5_eu_sales)
# Out:
# NA Sales example: [41.36 29.08 15.68 15.61 11.27]
# First 5 EU sales: [28.96  3.58 12.76 10.93  8.89]

# %% [markdown]
# #### Universal functions

# %%
normalized_sales = sales_data / np.max(sales_data, axis=0)
print("\nNormalized Sales Data (first 5 rows):")
print(normalized_sales[:5])

rounded_sales = np.round(sales_data[:5], 1)
print("\nRounded Sales Data (1 decimal):")
print(rounded_sales)
# Out:
# Normalized Sales Data (first 5 rows):
# [[1.         1.         0.36888454 0.79943236 1.        ]
#  [0.70309478 0.12361878 0.66634051 0.07284768 0.48758027]
#  [0.37911025 0.44060773 0.37084149 0.31125828 0.43038895]
#  [0.37741779 0.37741713 0.32093933 0.27909177 0.39706773]
#  [0.27248549 0.30697514 1.         0.09460738 0.3801042 ]]
#
# Rounded Sales Data (1 decimal):
# [[41.4 29.   3.8  8.4 82.5]
#  [29.1  3.6  6.8  0.8 40.2]
#  [15.7 12.8  3.8  3.3 35.5]
#  [15.6 10.9  3.3  3.  32.8]
#  [11.3  8.9 10.2  1.  31.4]]

# %% [markdown]
# #### Aggregations

# %%
print("\nMean sales by region:")
print("NA:", np.round(df['NA_Sales'].mean(), 3),
      "\nEU:", np.round(df['EU_Sales'].mean(), 3),
      "\nJP:", np.round(df['JP_Sales'].mean(), 3),
      "\nOther:", np.round(df['Other_Sales'].mean(), 3))
# Out:
# Mean sales by region:
# NA: 0.263
# EU: 0.145
# JP: 0.078
# Other: 0.047

# %% [markdown]
# #### Broadcasting

# %%
regional_weights = np.array([0.4, 0.3, 0.2, 0.1])  
weighted_sales = sales_data[:, :4] * regional_weights 

print("Regional weights:", regional_weights)
print("First 5 rows of original sales data:", sales_data[:5, :4])
print("First 5 rows of weighted sales:", weighted_sales[:5])
# Out:
# Regional weights: [0.4 0.3 0.2 0.1]
# First 5 rows of original sales data: [[41.36 28.96  3.77  8.45]
#  [29.08  3.58  6.81  0.77]
#  [15.68 12.76  3.79  3.29]
#  [15.61 10.93  3.28  2.95]
#  [11.27  8.89 10.22  1.  ]]
# First 5 rows of weighted sales: [[16.544  8.688  0.754  0.845]
#  [11.632  1.074  1.362  0.077]
#  [ 6.272  3.828  0.758  0.329]
#  [ 6.244  3.279  0.656  0.295]
#  [ 4.508  2.667  2.044  0.1  ]]

# %% [markdown]
# #### Boolean masking

# %%
high_sales_mask = sales_data[:, 4] > 10  # Games with >10M global sales
high_sellers = df[high_sales_mask]
high_sellers[['Name', 'Global_Sales']].sample(10)
# Out:
#                               Name  Global_Sales
# 16              Grand Theft Auto V         21.04
# 5                           Tetris         30.26
# 39         Super Smash Bros. Brawl         12.84
# 45                  Super Mario 64         11.89
# 51             Grand Theft Auto IV         11.01
# 56           Super Mario All-Stars         10.55
# 2                   Mario Kart Wii         35.52
# 53             Super Mario 3D Land         10.81
# 43     Animal Crossing: Wild World         12.13
# 55  Call of Duty: Modern Warfare 2         10.60

# %% [markdown]
# #### Sorting with argsort

# %%
sorted_indices = np.argsort(sales_data[:, 4])[::-1]
top_sellers = df.iloc[sorted_indices[:10]]
print("Top 10 Games by Global Sales (Descending Order):")
top_sellers[['Name', 'Platform', 'Year_of_Release', 'Global_Sales']]
# Out:
# Top 10 Games by Global Sales (Descending Order):
#                         Name Platform  Year_of_Release  Global_Sales
# 0                 Wii Sports      Wii           2006.0         82.53
# 1          Super Mario Bros.      NES           1985.0         40.24
# 2             Mario Kart Wii      Wii           2008.0         35.52
# 3          Wii Sports Resort      Wii           2009.0         32.77
# 4   Pokemon Red/Pokemon Blue       GB           1996.0         31.37
# 5                     Tetris       GB           1989.0         30.26
# 6      New Super Mario Bros.       DS           2006.0         29.80
# 7                   Wii Play      Wii           2006.0         28.92
# 8  New Super Mario Bros. Wii      Wii           2009.0         28.32
# 9                  Duck Hunt      NES           1984.0         28.31

# %% [markdown]
# #### Partial sorting

# %%
top_5_na_indices = np.argpartition(sales_data[:, 0], -5)[-5:]
top_5_na_games = df.iloc[top_5_na_indices].sort_values('NA_Sales', ascending=False)
print("Top 5 Games by North America Sales (Partial Sort):")
top_5_na_games[['Name', 'Platform', 'NA_Sales']]
# Out:
# Top 5 Games by North America Sales (Partial Sort):
#                 Name Platform  NA_Sales
# 0         Wii Sports      Wii     41.36
# 1  Super Mario Bros.      NES     29.08
# 9          Duck Hunt      NES     26.93
# 5             Tetris       GB     23.20
# 2     Mario Kart Wii      Wii     15.68

# %% [markdown]
# #### Structured Array

# %%
filtered_df = df[['Name', 'Platform', 'Year_of_Release', 'Global_Sales']].dropna()

dtype = [('name', 'U50'), ('platform', 'U10'), ('year', 'i4'), ('global_sales', 'f4')]

structured_array = np.array(
    list(zip(
        filtered_df['Name'],
        filtered_df['Platform'],
        filtered_df['Year_of_Release'].astype(int),
        filtered_df['Global_Sales']
    )),
    dtype=dtype
)
print("Structured Array Sample (First 5 Entries):")
print(structured_array[:5])
# Out:
# Structured Array Sample (First 5 Entries):
# [('Wii Sports', 'Wii', 2006, 82.53)
#  ('Super Mario Bros.', 'NES', 1985, 40.24)
#  ('Mario Kart Wii', 'Wii', 2008, 35.52)
#  ('Wii Sports Resort', 'Wii', 2009, 32.77)
#  ('Pokemon Red/Pokemon Blue', 'GB', 1996, 31.37)]

# %%
# Sorting structured array by global sales
structured_sorted = np.sort(structured_array, order='global_sales')[::-1]
print("Top 5 Games by Global Sales (Structured Array):")
print(structured_sorted[:5])
# Out:
# Top 5 Games by Global Sales (Structured Array):
# [('Wii Sports', 'Wii', 2006, 82.53)
#  ('Super Mario Bros.', 'NES', 1985, 40.24)
#  ('Mario Kart Wii', 'Wii', 2008, 35.52)
#  ('Wii Sports Resort', 'Wii', 2009, 32.77)
#  ('Pokemon Red/Pokemon Blue', 'GB', 1996, 31.37)]

# %% [markdown]
# #### Hierarchial Indexing

# %%
multi_index_df = df.set_index(["Genre", "Platform"])

print("=== Hierarchical Index DataFrame (First 10 Rows) ===")
print(multi_index_df[['Name']].head(10))
# Out:
# === Hierarchical Index DataFrame (First 10 Rows) ===
#                                             Name
# Genre        Platform
# Sports       Wii                      Wii Sports
# Platform     NES               Super Mario Bros.
# Racing       Wii                  Mario Kart Wii
# Sports       Wii               Wii Sports Resort
# Role-Playing GB         Pokemon Red/Pokemon Blue
# Puzzle       GB                           Tetris
# Platform     DS            New Super Mario Bros.
# Misc         Wii                        Wii Play
# Platform     Wii       New Super Mario Bros. Wii
# Shooter      NES                       Duck Hunt

# %%
# Get mean sales per (Genre, Platform)
genre_platform_sales = multi_index_df["Global_Sales"].groupby(level=[0, 1]).mean()

genre_platform_sales
# Out:
# Genre     Platform
# Action    2600        0.480984
#           3DS         0.310266
#           DC          0.420000
#           DS          0.331471
#           GB          1.320000
#                         ...
# Strategy  Wii         0.201200
#           WiiU        0.410000
#           X360        0.358214
#           XB          0.132381
#           XOne        0.140000
# Name: Global_Sales, Length: 293, dtype: float64

# %% [markdown]
# ### Advanced Operations

# %% [markdown]
# #### Creating a new column (Pandas)

# %%
df['Combined_Score'] = (df['Critic_Score'] * 0.7 + df['User_Score'] * 0.3)  # 70% critic, 30% user weight
print("\nTop 10 Games by Combined Score:")
df.sort_values('Combined_Score', ascending=False)[['Name', 'Critic_Score', 'User_Score', 'Combined_Score']].head(10)
# Out:
# Top 10 Games by Combined Score:
#                           Name  Critic_Score  User_Score  Combined_Score
# 5350               SoulCalibur          98.0         8.8           71.24
# 51         Grand Theft Auto IV          98.0         7.9           70.97
# 227   Tony Hawk's Pro Skater 2          98.0         7.7           70.91
# 57         Grand Theft Auto IV          98.0         7.5           70.85
# 517              Metroid Prime          97.0         9.3           70.69
# 97        Super Mario Galaxy 2          97.0         9.1           70.63
# 49          Super Mario Galaxy          97.0         8.9           70.57
# 129       Halo: Combat Evolved          97.0         8.6           70.48
# 38        Grand Theft Auto III          97.0         8.5           70.45
# 42          Grand Theft Auto V          97.0         8.3           70.39

# %% [markdown]
# ####  Concatenation along rows

# %%
# Creating a new row as a dictionary
new_game = {'Name': 'Future Game', 'Platform': 'PC', 'Year_of_Release': 2026,
            'Genre': 'Shooter', 'Publisher': 'New Studio', 'NA_Sales': 1.8,
            'EU_Sales': 0.5, 'JP_Sales': 0.3, 'Other_Sales': 0.2, 'Global_Sales': 2.8,
            'Critic_Score': 85, 'Critic_Count': 65, 'User_Score': 8.5, 'User_Count': 300,
            'Developer': 'Future Devs', 'Rating': 'M'}

new_game_df = pd.DataFrame([new_game])

df_appended = pd.concat([df, new_game_df], ignore_index=True)
df_appended.tail(2)
# Out:
#                       Name Platform  Year_of_Release       Genre   Publisher  \
# 16716  Winning Post 8 2016      PSV           2016.0  Simulation  Tecmo Koei
# 16717          Future Game       PC           2026.0     Shooter  New Studio
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 16716       0.0       0.0      0.01          0.0          0.01          71.0
# 16717       1.8       0.5      0.30          0.2          2.80          85.0
#
#        Critic_Count  User_Score  User_Count    Developer Rating  \
# 16716           NaN         7.5         NaN          NaN    NaN
# 16717          65.0         8.5       300.0  Future Devs      M
#
#        Combined_Score
# 16716           51.95
# 16717             NaN

# %% [markdown]
# #### Concatenation along columns

# %%
# Creating extra columns dataset
extra_info = pd.DataFrame({
    'Game_ID': range(1, len(df) + 1),  # Assigning unique IDs
    'Awards_Won': [np.random.randint(0, 5) for _ in range(len(df))]  # Random awards data
})

df_with_extra_info = pd.concat([df, extra_info], axis=1)
df_with_extra_info[['Name', 'Game_ID', 'Awards_Won']].head(3)
# Out:
#                 Name  Game_ID  Awards_Won
# 0         Wii Sports      1.0         2.0
# 1  Super Mario Bros.      2.0         4.0
# 2     Mario Kart Wii      3.0         0.0

# %% [markdown]
# #### Merging

# %%
publisher_details = pd.DataFrame({
    'Publisher': ['Nintendo', 'Sony', 'Microsoft', 'XYZ Games', 'ABC Studios'],
    'Headquarters': ['Japan', 'Japan', 'USA', 'India', 'UK']
})

# %% [markdown]
# Inner Join

# %%
df_merged = pd.merge(df, publisher_details, on='Publisher', how='inner')
df_merged[['Name', 'Publisher', 'Headquarters']].tail(3)
# Out:
#                                                   Name Publisher Headquarters
# 703  Mario & Luigi: Paper Jam & Mario Kart 7 Double...  Nintendo        Japan
# 704                                   Fast Racing Neo   Nintendo        Japan
# 705  Nintendogs and Cats Golden Retriever and New F...  Nintendo        Japan

# %% [markdown]
# Left Join

# %%
df_left_join = pd.merge(df, publisher_details, on='Publisher', how='left')
df_left_join[['Name', 'Publisher', 'Headquarters']].tail(3)
# Out:
#                           Name     Publisher Headquarters
# 16714  Haitaka no Psychedelica  Idea Factory          NaN
# 16715         Spirits & Spells       Wanadoo          NaN
# 16716      Winning Post 8 2016    Tecmo Koei          NaN

# %% [markdown]
# Right Join

# %%
df_right_join = pd.merge(df, publisher_details, on='Publisher', how='right')
df_right_join[['Name', 'Publisher', 'Headquarters']].tail(3)
# Out:
#     Name    Publisher Headquarters
# 707  NaN    Microsoft          USA
# 708  NaN    XYZ Games        India
# 709  NaN  ABC Studios           UK

# %% [markdown]
# Full Outer Join

# %%
df_outer_join = pd.merge(df, publisher_details, on='Publisher', how='outer')
df_outer_join[['Name', 'Publisher', 'Headquarters']].tail(3)
# Out:
#                               Name Publisher Headquarters
# 16718  Brothers in Arms: Furious 4       NaN          NaN
# 16719            Dance with Devils       NaN          NaN
# 16720       Driving Simulator 2011       NaN          NaN

# %% [markdown]
# #### Aggregation

# %%
# Aggregating total global sales by Genre
genre_sales = df.groupby('Genre')['Global_Sales'].sum()
genre_sales.head(10)
# Out:
# Genre
# Action          1745.27
# Adventure        237.69
# Fighting         447.48
# Misc             803.18
# Platform         828.08
# Puzzle           243.02
# Racing           728.90
# Role-Playing     934.40
# Shooter         1052.94
# Simulation       390.42
# Name: Global_Sales, dtype: float64

# %%
# Aggregating multiple statistics
agg_stats = df.groupby('Platform').agg({'Global_Sales': ['sum', 'mean', 'max']})
agg_stats.head(10)
# Out:
#          Global_Sales
#                   sum      mean    max
# Platform
# 2600            97.08  0.729925   7.81
# 3DO              0.10  0.033333   0.06
# 3DS            259.09  0.498250  14.60
# DC              15.97  0.307115   2.42
# DS             807.10  0.375046  29.80
# GB             255.45  2.606633  31.37
# GBA            318.50  0.387470  15.85
# GC             199.36  0.358561   7.07
# GEN             28.36  1.050370   6.03
# GG               0.04  0.040000   0.04

# %% [markdown]
# #### Group By

# %%
genre_sales = df.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=False)
genre_sales.head(5)
# Out:
# Genre
# Action          1745.27
# Sports          1332.00
# Shooter         1052.94
# Role-Playing     934.40
# Platform         828.08
# Name: Global_Sales, dtype: float64

# %%
platform_year_sales = df.groupby(['Platform', 'Year_of_Release'])['Global_Sales'].mean()
platform_year_sales
# Out:
# Platform  Year_of_Release
# 2600      1980.0             1.264444
#           1981.0             0.777609
#           1982.0             0.801667
#           1983.0             0.530000
#           1984.0             0.270000
#                                ...
# XB        2008.0             0.180000
# XOne      2013.0             0.996842
#           2014.0             0.887541
#           2015.0             0.751125
#           2016.0             0.301954
# Name: Global_Sales, Length: 241, dtype: float64

# %% [markdown]
# ### Pivot Tables

# %%
pivot1 = pd.pivot_table(df, 
                        index='Genre', 
                        columns='Rating', 
                        values='Global_Sales', 
                        aggfunc='mean',
                        fill_value=0)
pivot1
# Out:
# Rating          AO         E      E10+     EC    K-A         M     RP  \
# Genre
# Action        1.95  0.477019  0.455385  0.450  0.000  0.989836  0.000
# Adventure     0.00  0.358086  0.172500  0.180  0.000  0.425758  0.000
# Fighting      0.00  0.136250  0.240000  0.000  0.000  0.587755  0.000
# Misc          0.00  0.633239  0.689401  0.194  1.920  0.267692  0.000
# Platform      0.00  0.921229  0.421042  0.000  0.000  0.533333  0.000
# Puzzle        0.00  0.305121  0.519302  0.000  0.000  0.000000  0.000
# Racing        0.00  0.632034  0.585417  0.000  0.000  0.276111  0.010
# Role-Playing  0.00  0.839048  0.454775  0.000  0.000  0.949815  0.000
# Shooter       0.00  0.090000  0.359310  0.000  0.000  1.108938  0.000
# Simulation    0.00  0.493067  0.455208  0.000  0.000  0.264000  0.000
# Sports        0.00  0.712012  0.501495  0.000  0.000  0.244375  0.000
# Strategy      0.00  0.297714  0.248205  0.000  1.205  0.214800  0.035
#
# Rating               T
# Genre
# Action        0.490103
# Adventure     0.168174
# Fighting      0.625939
# Misc          0.543013
# Platform      0.370781
# Puzzle        0.251000
# Racing        0.561221
# Role-Playing  0.570214
# Shooter       0.576063
# Simulation    0.490947
# Sports        0.479091
# Strategy      0.210247

# %%
pivot2 = pd.pivot_table(df,
                            index='Genre',
                            columns='Rating',
                            values='Global_Sales',
                            aggfunc=['mean', 'max', 'sum'],
                            fill_value=0)
pivot2
# Out:
#               mean                                                     \
# Rating          AO         E      E10+     EC    K-A         M     RP
# Genre
# Action        1.95  0.477019  0.455385  0.450  0.000  0.989836  0.000
# Adventure     0.00  0.358086  0.172500  0.180  0.000  0.425758  0.000
# Fighting      0.00  0.136250  0.240000  0.000  0.000  0.587755  0.000
# Misc          0.00  0.633239  0.689401  0.194  1.920  0.267692  0.000
# Platform      0.00  0.921229  0.421042  0.000  0.000  0.533333  0.000
# Puzzle        0.00  0.305121  0.519302  0.000  0.000  0.000000  0.000
# Racing        0.00  0.632034  0.585417  0.000  0.000  0.276111  0.010
# Role-Playing  0.00  0.839048  0.454775  0.000  0.000  0.949815  0.000
# Shooter       0.00  0.090000  0.359310  0.000  0.000  1.108938  0.000
# Simulation    0.00  0.493067  0.455208  0.000  0.000  0.264000  0.000
# Sports        0.00  0.712012  0.501495  0.000  0.000  0.244375  0.000
# Strategy      0.00  0.297714  0.248205  0.000  1.205  0.214800  0.035
#
#                          max         ...                sum                  \
# Rating               T    AO      E  ...    RP      T    AO       E    E10+
# Genre                                ...
# Action        0.490103  1.95   8.16  ...  0.00   7.15  1.95  198.44  219.04
# Adventure     0.168174  0.00   3.14  ...  0.00   1.87  0.00   58.01   11.73
# Fighting      0.625939  0.00   0.27  ...  0.00  12.84  0.00    1.09    4.56
# Misc          0.543013  0.00  28.92  ...  0.00   5.12  0.00  289.39  115.13
# Platform      0.370781  0.00  29.80  ...  0.00   2.78  0.00  329.80   60.63
# Puzzle        0.251000  0.00  15.29  ...  0.00   0.80  0.00   88.18   22.33
# Racing        0.561221  0.00  35.52  ...  0.01   9.49  0.00  369.74   56.20
# Role-Playing  0.570214  0.00   7.72  ...  0.00   9.72  0.00   70.48   50.48
# Shooter       0.576063  0.00   0.46  ...  0.00   6.83  0.00    4.32   20.84
# Simulation    0.490947  0.00  12.13  ...  0.00   8.01  0.00  160.74   21.85
# Sports        0.479091  0.00  82.53  ...  0.00   5.02  0.00  845.87   53.66
# Strategy      0.210247  0.00   2.08  ...  0.04   4.84  0.00   20.84   19.36
#
#
# Rating          EC   K-A       M    RP       T
# Genre
# Action        0.45  0.00  601.82  0.00  333.76
# Adventure     0.36  0.00   42.15  0.00   19.34
# Fighting      0.00  0.00   28.80  0.00  226.59
# Misc          0.97  1.92    3.48  0.00  129.78
# Platform      0.00  0.00    1.60  0.00   23.73
# Puzzle        0.00  0.00    0.00  0.00    2.51
# Racing        0.00  0.00    4.97  0.01   96.53
# Role-Playing  0.00  0.00  153.87  0.00  239.49
# Shooter       0.00  0.00  626.55  0.00  200.47
# Simulation    0.00  0.00    1.32  0.00   93.28
# Sports        0.00  0.00    3.91  0.00   94.86
# Strategy      0.00  2.41    5.37  0.07   34.06
#
# [12 rows x 24 columns]

# %%
pivot3 = pd.pivot_table(df,
                       index='Genre',
                       values=['Critic_Score', 'User_Score'],
                       aggfunc='mean')
pivot3
# Out:
#               Critic_Score  User_Score
# Genre
# Action           68.548665    7.257834
# Adventure        69.594781    7.415503
# Fighting         70.141343    7.407185
# Misc             69.690857    7.329257
# Platform         69.353604    7.404279
# Puzzle           69.618966    7.428276
# Racing           69.196157    7.261970
# Role-Playing     71.812000    7.559200
# Shooter          70.415722    7.180045
# Simulation       70.041190    7.356178
# Sports           71.492334    7.246891
# Strategy         71.480234    7.406735

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# #### Pie Chart

# %%
region_sales = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].sum()
plt.figure(figsize=(4, 4))
plt.pie(region_sales, labels=region_sales.index, autopct='%1.1f%%')
plt.title('Market Share by Region')
plt.show()

# %% [markdown]
# #### Bar Graph

# %%
genre_sales2 = df.groupby('Genre')['Global_Sales'].sum()

plt.figure(figsize=(12, 6))
genre_sales2.plot(kind='bar')
plt.title('Total Global Sales by Genre')
plt.ylabel('Sales (in millions)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Line Plot

# %%
yearly_sales = df.groupby('Year_of_Release')['Global_Sales'].sum()
plt.figure(figsize=(10, 5))
yearly_sales.plot(kind='line', marker='o')
plt.title('Video Game Sales Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Total Global Sales (in millions)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Scatter Plot

# %%
df2 = df.sample(500)
top_genres = df2['Genre'].value_counts().nlargest(3).index

df_top_genres = df2[df2['Genre'].isin(top_genres)]

plt.figure(figsize=(6, 4))

# Create scatter plot with only top genres
scatter = sns.scatterplot(
    data=df_top_genres,
    x='Critic_Score',
    y='User_Score',
    hue='Genre',
    palette='bright',  
    alpha=0.8,
    s=80,
    edgecolor='w',
    linewidth=0.5
)

plt.title('Critic vs User Scores (Top 5 Genres)', fontsize=14, pad=15)
plt.xlabel('Critic Score (0-100)', fontsize=12)
plt.ylabel('User Score (0-10)', fontsize=12)

plt.legend(
    title='Genre',
    bbox_to_anchor=(1.05, 0.95),
    loc='upper left',
    frameon=True,
    framealpha=0.9
)

plt.show()

# %% [markdown]
# #### Box Plot

# %%
top_platforms = df['Platform'].value_counts().index[:10]
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[df['Platform'].isin(top_platforms)],
            x='Platform',
            y='Global_Sales')
plt.title('Sales Distribution by Platform (Top 10)')
plt.yscale('log')  # Log scale for better visualization
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Visualizing Errors

# %%
means = df[['NA_Sales', 'EU_Sales', 'JP_Sales']].mean()
errors = df[['NA_Sales', 'EU_Sales', 'JP_Sales']].std()

plt.bar(means.index, means.values, yerr=errors.values, capsize=5)
plt.title('Sales by Region with Error Bars')
plt.show()

# %% [markdown]
# #### Histogram and Binning

# %%
plt.subplot(1, 2, 2)
plt.hist(df['Year_of_Release'].dropna(), bins=30, color='salmon', edgecolor='black')
plt.title('Game Releases by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
bin_sizes = [10, 20, 50, 'auto']
for i, bins in enumerate(bin_sizes, 1):
    plt.subplot(2, 2, i)
    plt.hist(df['Critic_Score'].dropna(), bins=bins, color='lightgreen', edgecolor='black')
    plt.title(f'Critic Score Distribution (bins={bins})')
    plt.xlabel('Score')
    plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Multiple Subplots

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Subplot 1
axes[0, 0].scatter(df['Critic_Score'], df['Global_Sales'], alpha=0.5)
axes[0, 0].set_title('Critic Score vs Global Sales')
axes[0, 0].set_xlabel('Critic Score')
axes[0, 0].set_ylabel('Global Sales (millions)')

# Subplot 2
sales_by_region = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].mean()
axes[0, 1].bar(sales_by_region.index, sales_by_region.values, color=['blue', 'green', 'red', 'purple'])
axes[0, 1].set_title('Average Sales by Region')
axes[0, 1].set_ylabel('Sales (millions)')

# Subplot 3
genre_counts = df['Genre'].value_counts().head(10)
axes[1, 0].pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%')
axes[1, 0].set_title('Top 10 Game Genres')

# Subplot 4
platform_counts = df['Platform'].value_counts().head(8)
axes[1, 1].barh(platform_counts.index, platform_counts.values, color='orange')
axes[1, 1].set_title('Top 8 Platforms by Game Count')
axes[1, 1].set_xlabel('Number of Games')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3D Plotting (using Axes3D)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['NA_Sales'], df['EU_Sales'], df['JP_Sales'])
ax.set_xlabel('NA Sales')
ax.set_ylabel('EU Sales')
ax.set_zlabel('JP Sales')
plt.title('3D Scatter Plot')
plt.show()

# %% [markdown]
# #### 3D Surface Plot: Sales Distribution by Region

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(df['NA_Sales'].min(), df['NA_Sales'].max(), 20)
y = np.linspace(df['EU_Sales'].min(), df['EU_Sales'].max(), 20)
X, Y = np.meshgrid(x, y)
Z = np.sqrt(X**2 + Y**2)  

ax.plot_surface(X, Y, Z, cmap='plasma', alpha=0.8)
ax.set_xlabel('NA Sales')
ax.set_ylabel('EU Sales')
ax.set_zlabel('Sales Magnitude')
ax.set_title('3D Surface: NA vs. EU Sales Relationship')
plt.show()

# %% [markdown]
# #### 3D Contour Plot: Review Scores vs. Sales

# %%
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

# Create grid
x = np.linspace(0, 100, 20)  # Critic score range
y = np.linspace(0, 10, 20)   # User score range
X, Y = np.meshgrid(x, y)
Z = np.sin(X/10) * np.cos(Y/2) * 50  # Simulated sales surface

# Plot
ax.contour3D(X, Y, Z, 50, cmap='magma')
ax.set_xlabel('Critic Score')
ax.set_ylabel('User Score')
ax.set_zlabel('Sales Impact')
ax.set_title('3D Contour: Hypothetical Sales Impact from Review Scores')
plt.show()

# %% [markdown]
# ## Inferential Statistics

# %% [markdown]
# #### Normal Distribution

# %%
from scipy.stats import norm

# Drop missing values from Critic_Score
scores = df['Critic_Score'].dropna()

# Standardize
z_scores = (scores - scores.mean()) / scores.std()

# Plot
plt.figure(figsize=(10, 6))
sns.histplot(z_scores, bins=30, kde=True, stat="density", color='skyblue', label='Standardized Critic Scores')

# Overlay ideal normal distribution
x = np.linspace(-4, 4, 100)
plt.plot(x, norm.pdf(x), color='red', label='Ideal Normal Distribution')

plt.title("Normal Distribution using Standardized Critic Scores")
plt.xlabel("Z-Score")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Poisson Distribution

# %%
from scipy.stats import poisson

mu = df['User_Count'].dropna().mean()
x = range(0, int(mu)*2)
pmf = poisson.pmf(x, mu)

plt.bar(x, pmf)
plt.title('Poisson Distribution of User_Count')
plt.xlabel('User Count')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# #### Bernoulli Distribution (binary outcome: rating E or not)

# %%
from scipy.stats import bernoulli

df['is_E'] = df['Rating'] == 'E'
p = df['is_E'].mean()

x = [0, 1]
pmf = bernoulli.pmf(x, p)

plt.bar(x, pmf)
plt.xticks([0, 1], ['Not E', 'E'])
plt.title('Bernoulli Distribution of Rating E')
plt.show()

# %% [markdown]
# #### Z-Score & Outlier Detection

# %%
from scipy.stats import zscore

df['Global_Sales_Z'] = zscore(df['Global_Sales'].fillna(0))
outliers = df[df['Global_Sales_Z'].abs() > 3]
outliers[['Name', 'Global_Sales', 'Global_Sales_Z']]
# Out:
#                                               Name  Global_Sales  \
# 0                                       Wii Sports         82.53
# 1                                Super Mario Bros.         40.24
# 2                                   Mario Kart Wii         35.52
# 3                                Wii Sports Resort         32.77
# 4                         Pokemon Red/Pokemon Blue         31.37
# ..                                             ...           ...
# 185                        New Super Mario Bros. U          5.22
# 186  Dragon Quest VIII: Journey of the Cursed King          5.21
# 187                            Super Mario Bros. 3          5.20
# 188       Professor Layton and the Curious Village          5.19
# 189                 Super Mario Land 3: Wario Land          5.19
#
#      Global_Sales_Z
# 0         52.972422
# 1         25.651711
# 2         22.602438
# 3         20.825849
# 4         19.921403
# ..              ...
# 185        3.027656
# 186        3.021195
# 187        3.014735
# 188        3.008275
# 189        3.008275
#
# [190 rows x 3 columns]

# %% [markdown]
# #### Confidence Interval

# %%
import scipy.stats as stats
import numpy as np

sample = df['Global_Sales'].dropna()
mean = sample.mean()
std = sample.std()
n = len(sample)
conf_int = stats.norm.interval(0.95, loc=mean, scale=std/np.sqrt(n))
print("95% Confidence Interval:", conf_int)
# Out:
# 95% Confidence Interval: (np.float64(0.5099963653120693), np.float64(0.5569271257449385))

# %% [markdown]
# #### Correlation Matrix

# %%
numeric_cols = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score', 'User_Score']
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### F-Distribution & ANOVA

# %%
import scipy.stats as stats

genres = df.dropna(subset=['Genre', 'Global_Sales'])
groups = [group['Global_Sales'].values for name, group in genres.groupby('Genre')]
f_stat, p_val = stats.f_oneway(*groups)
print("ANOVA F-statistic:", f_stat, "p-value:", p_val)
# Out:
# ANOVA F-statistic: 18.747384734633812 p-value: 6.770686930729134e-38

# %% [markdown]
# #### Chi-Square Test of Independence (Genre vs Rating)

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['Genre'], df['Rating'])
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi2 statistic: {chi2:.2f}, p-value: {p:.10f}")
# Out:
# Chi2 statistic: 5255.67, p-value: 0.0000000000
